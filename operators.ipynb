# %%
### 2B OPERATORS
a=int(input("enter a "))
b=int(input("enter b"))
print(a>b)
print(a<b)

# %%
## 1C ASSIGNMENT OPERATOR
a=int(input("enetr a"))
a*=10
a+=5
b=a
print("a=",a)
print("b=",b)

# %%
## 1E MEMBERSHIP OPERATORS
a=[1,2,3]
print(2 in a)

# %%
a=[1,2,3]
print(5 in a)

# %%
a=[1,2,3]
print(4 not in a)

# %%
## 1F IDENTITY OPERATOR
a=[1,2,3]
b=[1,2,3]
print(a is b)
print(a==b)
c=b
print(b is c)
# Out:
# False
# True
# True
