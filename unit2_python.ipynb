# %%
## lists
lst=[1,2,3,4,5,6]
print(lst)
lst.append(6)
print(lst)
lst.remove(4)
print(lst)
print(lst[0])
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6, 6]
# [1, 2, 3, 5, 6, 6]
# 1

# %%
list = [5,6,8,2,3]
list.sort()
print(list)
# Out:
# [2, 3, 5, 6, 8]
