# %%
### functions
### program_to_find_sum_of_2_no's_using_functions
def sum(a,b):
    return a+b
r=sum(5,10)
print(r)
print(sum(5,10))
# Out:
# 15
# 15

# %%
def sum(a,b):
    return a+b
x=sum(5,10)
print("sum=",x)
# Out:
# sum= 15

# %%
def sum(a,b):
    return a+b
a=int(input("enter 1st no:"))
b=int(input("enert 2nd no:"))
x=sum(5,10)
print("sum+",x)
# Out:
# sum+ 15

# %%
### even or odd
def even_odd(n):
    if (n%2==0):
        print("even")
    else:
        print("odd")
        
        
n=int(input("enter a no:"))
even_odd(n)
# Out:
# even

# %%
### find max of 3 numbers 
def maximum(a,b,c):
    return max(a,b,c)


print(maximum(10,20,30))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[13], line 6
#       2 def maximum(a,b,c):
#       3     return max(a,b,c)
# ----> 6 print(maximum(10,20,30))
#
# Cell In[13], line 3, in maximum(a, b, c)
#       2 def maximum(a,b,c):
# ----> 3     return max(a,b,c)
#
# Cell In[7], line 3, in max(a, b, c)
#       2 def max(a,b,c):
# ----> 3     return max(a,b,c)
#
# Cell In[7], line 3, in max(a, b, c)
#       2 def max(a,b,c):
# ----> 3     return max(a,b,c)
#
#     [... skipping similar frames: max at line 3 (2973 times)]
#
# Cell In[7], line 3, in max(a, b, c)
#       2 def max(a,b,c):
# ----> 3     return max(a,b,c)
#
# RecursionError: maximum recursion depth exceeded
